# %% [markdown]
# # AI职业顾问系统 - 演示Notebook
#
# 这个notebook演示如何使用AI职业顾问系统的各个组件。

# %%
import sys
sys.path.append('../src')

from agent.career_advisor_agent import CareerAdvisorAgent
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. 创建AI职业顾问Agent

# %%
agent = CareerAdvisorAgent()
print(agent.chat('你好'))

# %% [markdown]
# ## 2. 薪资预测示例

# %%
response = agent.chat('我会Python和SQL,能拿多少薪水?')
print(response)

# %% [markdown]
# ## 3. 技能推荐示例

# %%
response = agent.chat('我想学习新技能,有什么建议?')
print(response)

# %% [markdown]
# ## 4. 职位推荐示例

# %%
response = agent.chat('推荐适合我的职位')
print(response)

# %% [markdown]
# ## 5. 综合建议示例

# %%
agent.reset()  # 重置上下文
response = agent.chat('我是中级工程师,会Python、SQL、Docker、AWS,想拿15万年薪')
print(response)
